# %%
import matplotlib.pyplot as plt
import numpy as np

def gradient_descent(f, learning_rate, initial_point):
    
    def deriv(f, base_point): #estimate the derivative of the function f at base poin
        return (f(base_point+10**(-5))-f(base_point))/(10**(-5))

    x_coords = [initial_point] #this list is where you will store the x_n's
    y_coords = [f(initial_point)] #this list is where you will store the y_n's
    
    # Gradient descent loop
    for _ in range(100):  # You can adjust the number of iterations
        gradient = deriv(f, x_coords[-1])
        update = -learning_rate * gradient
        new_x = x_coords[-1] + update
        x_coords.append(new_x)
        y_coords.append(f(new_x))

    # Plotting
    plot_range=np.linspace(min(x_coords)-0.5,max(x_coords)+0.5,10000) #to make look good
    function_range=[f(i) for i in plot_range]
    plt.plot(plot_range, function_range) #this plots the function f(x)
    plt.plot(x_coords, y_coords) #this will plot the sequence of points x_n, f(x_n)

    return round(x_coords[-1], 3), round(y_coords[-1], 3) #return your last x_n and y_n, rounded to three decimal places

# Example usage for f(x) = x^2:
def function_x_squared(x):
    return x**2

learning_rate_x_squared = 0.1
initial_point_x_squared = 2.0
result_x_squared = gradient_descent(function_x_squared, learning_rate_x_squared, initial_point_x_squared)

print("Result for f(x) = x^2:", result_x_squared)
# Out:
# Result for f(x) = x^2: (-0.0, 0.0)

# %%
import matplotlib.pyplot as plt
import numpy as np

def gradient_descent(f, learning_rate, initial_point):
    
    def deriv(f, base_point): #estimate the derivative of the function f at base poin
        return (f(base_point+10**(-5))-f(base_point))/(10**(-5))

    x_coords = [initial_point] #this list is where you will store the x_n's
    y_coords = [f(initial_point)] #this list is where you will store the y_n's
    
    # Gradient descent loop
    for _ in range(100):  # You can adjust the number of iterations
        gradient = deriv(f, x_coords[-1])
        update = -learning_rate * gradient
        new_x = x_coords[-1] + update
        x_coords.append(new_x)
        y_coords.append(f(new_x))

    # Plotting
    plot_range=np.linspace(min(x_coords)-0.5,max(x_coords)+0.5,10000) #to make look good
    function_range=[f(i) for i in plot_range]
    plt.plot(plot_range, function_range) #this plots the function f(x)
    plt.plot(x_coords, y_coords) #this will plot the sequence of points x_n, f(x_n)

    return round(x_coords[-1], 3), round(y_coords[-1], 3) #return your last x_n and y_n, rounded to three decimal places

# Example usage for f(x) = -3x^3+ 10x^2 -5x-3:
def function_f_x(x):
    return -3*x**3 + 10*x**2 - 5*x - 3

learning_rate_f_x = 0.01
initial_point_f_x = -2.0
result_f_x = gradient_descent(function_f_x, learning_rate_f_x, initial_point_f_x)

print("Result for f(x) = -3x^3 + 10x^2 - 5x - 3:", result_f_x)
# Out:
# Result for f(x) = -3x^3 + 10x^2 - 5x - 3: (0.287, -3.682)
